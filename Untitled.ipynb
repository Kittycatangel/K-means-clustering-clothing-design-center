# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-import" data-toc-modified-id="Data-import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data import</a></span></li><li><span><a href="#Data-Cleasning" data-toc-modified-id="Data-Cleasning-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Cleasning</a></span></li><li><span><a href="#Scatter-plot" data-toc-modified-id="Scatter-plot-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Scatter plot</a></span></li><li><span><a href="#Clustering-Using-K-Means" data-toc-modified-id="Clustering-Using-K-Means-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Clustering Using K-Means</a></span></li><li><span><a href="#Finding-the-Optimal-Size-Classes" data-toc-modified-id="Finding-the-Optimal-Size-Classes-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Finding the Optimal Size Classes</a></span></li><li><span><a href="#Clustering-Using-K-Means-(K=4)" data-toc-modified-id="Clustering-Using-K-Means-(K=4)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Clustering Using K-Means (K=4)</a></span></li></ul></div>

# %% [markdown]
# # Data import

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
df = pd.read_csv("BMX_G.csv")

# %% [markdown]
# # Data Cleasning

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# seqn             0
# bmdstats         0
# bmxwt           95
# bmiwt         8959
# bmxrecum      8259
# bmirecum      9307
# bmxhead       9102
# bmihead       9338
# bmxht          723
# bmiht         9070
# bmxbmi         736
# bmdbmic       5983
# bmxleg        2383
# bmileg        8984
# bmxarml        512
# bmiarml       8969
# bmxarmc        512
# bmiarmc       8965
# bmxwaist      1134
# bmiwaist      8882
# bmxsad1       2543
# bmxsad2       2543
# bmxsad3       8940
# bmxsad4       8940
# bmdavsad      2543
# bmdsadcm      8853
# dtype: int64

# %%
# remove rows with NaNs
df = df.dropna(subset=['bmxleg','bmxwaist']) 
print(df.shape)
# Out:
# (6899, 27)

# %% [markdown]
# # Scatter plot

# %%
import matplotlib.pyplot as plt
plt.scatter(df['bmxleg'],df['bmxwaist'], c='r', s=2)
plt.xlabel("Upper leg Length (cm)")
plt.ylabel("Waist Circumference (cm)")
# Out:
# Text(0, 0.5, 'Waist Circumference (cm)')

# %% [markdown]
# # Clustering Using K-Means (K=2)

# %%
#---using sci-kit-learn---
from sklearn.cluster import KMeans
k = 2
X = np.array(list(zip(df['bmxleg'],df['bmxwaist'])))
kmeans = KMeans(n_clusters=k)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
#---map the labels to colors---
c = ['b','r','y','g','c','m']
colors = [c[i] for i in labels]
plt.scatter(df['bmxleg'],df['bmxwaist'], c=colors, s=2)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=100, c='black')

# %%
# vlaue of two centroids
print(centroids)
# Out:
# [[ 37.65653117  77.88428184]
#  [ 38.8224369  107.96612652]]

# %% [markdown]
# # Finding the Optimal Size Classes

# %%
from sklearn import metrics
silhouette_avgs = []
min_k = 2
#---try k from 2 to maximum number of labels---
for k in range(min_k, 10):
    kmean = KMeans(n_clusters=k).fit(X)
    score = metrics.silhouette_score(X, kmean.labels_)
    print("Silhouette Coefficients for k =", k, "is", score)
    silhouette_avgs.append(score)
#---the optimal k is the one with the highest average silhouette---
Optimal_K = silhouette_avgs.index(max(silhouette_avgs)) + min_k
print("Optimal K is", Optimal_K)
# Out:
# Silhouette Coefficients for k = 2 is 0.5165351076055341
# Silhouette Coefficients for k = 3 is 0.47226905068761915
# Silhouette Coefficients for k = 4 is 0.4361974023863329
# Silhouette Coefficients for k = 5 is 0.4189717550749686
# Silhouette Coefficients for k = 6 is 0.3936454185144895
# Silhouette Coefficients for k = 7 is 0.3767794599578412
# Silhouette Coefficients for k = 8 is 0.36047082481782344
# Silhouette Coefficients for k = 9 is 0.34140182362027593
# Optimal K is 2

# %% [markdown]
# # Clustering Using K-Means (K=4)

# %%
#---using sci-kit-learn---
from sklearn.cluster import KMeans
k = 4
X = np.array(list(zip(df['bmxleg'],df['bmxwaist'])))
kmeans = KMeans(n_clusters=k)
kmeans = kmeans.fit(X)
labels = kmeans.predict(X)
centroids = kmeans.cluster_centers_
#---map the labels to colors---
c = ['b','r','y','g','c','m']
colors = [c[i] for i in labels]
plt.scatter(df['bmxleg'],df['bmxwaist'], c=colors, s=2)
plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=100, c='black')

# %%
print(centroids)
# Out:
# [[ 38.7338317   85.14023921]
#  [ 38.58335247 124.252124  ]
#  [ 38.88794803 102.30430108]
#  [ 36.05079038  67.3375945 ]]
